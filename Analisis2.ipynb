# %% [markdown]
# # Data selection
#
# ### As a data engineer you have asked all the employees to show their preferences on where to place the new office. Your goal is to place the new company offices in the best place for the company to grow. You have to find a place that more or less covers all the following requirements (note that it's impossible to cover all requirements, so you have to prioritize at your glance):
#
# #### - Designers like to go to design talks and share knowledge. There must be some nearby companies that also do design.
# #### - 30% of the company staff have at least 1 child.
# #### - Developers like to be near successful tech startups that have raised at least 1 Million dollars.
# #### - Executives like Starbucks A LOT. Ensure there's a starbucks not too far.
# #### - Account managers need to travel a lot.
# #### - Everyone in the company is between 25 and 40, give them some place to go party.
# #### - The CEO is vegan.
# #### - If you want to make the maintenance guy happy, a basketball stadium must be around 10 Km.
# #### - The office dog—"Dobby" needs a hairdresser every month. Ensure there's one not too far away.

# %%
# %run -i 'src/mongo.py'

# %%
c = mongo("ironhack","companies")
c
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ironhack'), 'companies')

# %%
tech = startups(1000000,2009)
# Out:
# 88  companies.

# %%
design1 = design()
# Out:
# 37  companies.

# %%
# %run -i 'src/locations.py'

# %%
tech_location = offices_location(tech)
# Out:
# 117  companies.
#  58  full location information.

# %%
design_location = offices_location(design1)
# Out:
# 45  companies.
#  29  full location information.

# %%
df = pd.concat([design_location, tech_location], axis = 0)
df_unique = df.drop_duplicates(subset = ["name"])
df_unique
# Out:
#              name   office description  office latitude  office longitude
# 0         SmugMug                             37.390056       -122.067692
# 1       Clipmarks                 None        40.757929        -73.985506
# 3         BeFunky                 None        37.774929       -122.419415
# 6           Youku                             31.200657        121.438470
# 8     Gilt Groupe      New York Office        40.747270        -73.980064
# ..            ...                  ...              ...               ...
# 104        Z2Live               Z2Live        47.610301       -122.339978
# 107     Gridstore            Gridstore        37.418907       -122.088429
# 108     HyperWeek                             46.212146          6.150324
# 109          Meez                             37.785271       -122.397582
# 116  Titan Gaming  Santa Monica Office        53.544711       -113.515769
#
# [73 rows x 4 columns]

# %%
# %run -i 'src/maps.py'

# %%
heat_map = create_heatmap(df_unique)
heat_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_208351283bb51c458c6e9ebd9110014f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_208351283bb51c458c6e9ebd9110014f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_208351283bb51c458c6e9ebd9110014f = L.map(
#                 &quot;map_208351283bb51c458c6e9ebd9110014f&quot;,
#                 {
#                     center: [37.390056, -122.067692],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64e6e54b1527dcb90b6235222f43b915 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_208351283bb51c458c6e9ebd9110014f);
#
#
#             var heat_map_da31b95e218c83fc952717c31bb50fe8 = L.heatLayer(
#                 [[37.390056, -122.067692], [40.757929, -73.985506], [37.7749295, -122.4194155], [31.2006566, 121.4384701], [40.74727, -73.9800645], [47.676378, -122.122155], [40.646166, -73.889492], [37.7955307, -122.4005983], [37.7749295, -122.4194155], [33.989029, -118.462421], [36.13996, -86.796377], [40.730763, -74.000827], [40.0018743, -75.2747196], [37.406027, -121.918642], [40.7277189, -73.9508211], [4.5980556, -74.0758333], [39.661171, -105.352174], [42.6866911, 23.316708], [45.7968414, -122.6931439], [43.264499, -2.9308322], [37.5646055, -122.3229235], [-23.5489433, -46.6388182], [40.026, -105.259041], [40.7078343, -74.0136605], [32.0554, 34.7595], [40.4455155, -3.7061764], [12.9349604, 77.6136847], [48.8566667, 2.3509871], [21.303049, -157.78907], [37.5645375, -122.3254705], [49.2824551, -123.109217], [41.4063346, 2.1920231], [40.757929, -73.985506], [42.603532, -83.16134], [50.83997, 4.3464721], [39.9052263, -86.0547016], [37.270518, -121.955879], [52.3657578, 4.8928722], [40.7408042, -74.00717], [37.4484914, -122.1802812], [51.51819, -0.208979], [47.3912899, 8.5082891], [34.052187, -118.243425], [37.6656476, -122.3843489], [39.749671, -104.9998449], [42.3647559, -71.1032591], [42.275263, -71.24762], [37.3229727, -122.0385792], [47.490346, 19.059078], [37.446823, -122.161523], [40.73343, -73.990967], [51.8205815, 0.0118608], [42.6751888, -71.1469003], [40.438423, -80.001933], [29.7847641, -82.4768036], [37.7905538, -122.4041485], [51.5196135, -0.1020265], [40.7481039, -74.0353787], [37.566879, -122.323895], [42.3756409, -72.5196907], [37.5561712, -122.0780632], [33.8171, -111.9035], [42.318138, -71.24756], [40.5932386, -105.0766501], [34.007112, -118.489748], [37.5252461, -121.9178417], [40.744618, -73.987764], [34.047312, -118.445243], [47.6103008, -122.3399782], [37.4189073, -122.0884286], [46.2121463, 6.1503245], [37.785271, -122.397582], [53.544711, -113.515769]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             ).addTo(map_208351283bb51c458c6e9ebd9110014f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
city_names = ["San_Francisco", "Los_Angeles", "New_York"]
cities = cities_loc(city_names)
cities
# Out:
# {'San_Francisco': <POLYGON ((-122.241 38.23, -122.312 38.227, -122.383 38.219, -122.452 38.205...>,
#  'Los_Angeles': <POLYGON ((-118.113 34.81, -118.207 34.807, -118.3 34.795, -118.392 34.776, ...>,
#  'New_York': <POLYGON ((-73.977 41.103, -74.021 41.102, -74.064 41.097, -74.107 41.089, -...>}

# %%
tech_data_clean = add_city_name(tech_location, cities)
tech_data_clean["type"] = "tech"
tech_data_clean
# Out:
#                                           name   office description
# 0                                    Sofa Labs                       \
# 2                                   Brandsclub
# 3                              Clovis Oncology                   HQ
# 4                            GameChanger Media      New York Office
# 5                                      Moblica                   HQ
# 6                                     ticketea               Office
# 7                               Althea Systems                   HQ
# 8                                        Ykone   Ykone Headquarters
# 12                                   travelmob                   HQ
# 13                                     Skydeck
# 14                                  Tiny Speck
# 15                                     Teambox     Barcelona Office
# 17                                     PeekYou                 None
# 18                                      Delphi
# 20                                      Getyoo                   HQ
# 21                                  Formspring           Formspring
# 22                                    VisualOn         Headquarters
# 23                                       Layar                   HQ
# 25                               ChallengePost
# 26                                     Factery
# 28                                   travelmob                   HQ
# 33                                      Pixsta                 None
# 34                                GetYourGuide         Headquarters
# 39                                     Magento                 None
# 40                       VistaGen Therapeutics
# 43                                  UsingMiles         Headquarters
# 45                                 Shareaholic          Shareaholic
# 46                               BrandYourself
# 48                                     ScaleMP
# 49                                       Prezi      Budapest Office
# 57                       Social Gaming Network       HQ Los Angeles
# 58                       Social Gaming Network
# 59                                   Chartbeat
# 60                                      ipadio
# 69                                     AppZero                   HQ
# 70                               The Resumator
# 71   Applied Genetics Technologies Corporation         Headquarters
# 72                                      Heyzap         Head Quaters
# 73                                       Shutl            LaunchPad
# 74                                   Integrate        Scottsdale HQ
# 78                                       Fixya
# 79                                    Tinychat          Home Office
# 80                                 BASH Gaming            US Office
# 81                                 BASH Gaming         India Office
# 82                                  UsingMiles         Headquarters
# 83                                       GENWI
# 84                                     AppNeta              AppNeta
# 85                              Solix Biofuels       Solix Biofuels
# 88                                      Tongal         Headquarters
# 89                     Advanced Power Projects
# 90                                       Yipit                   HQ
# 91                                   Integrate        Scottsdale HQ
# 103                                 RazorGator                 None
# 104                                     Z2Live               Z2Live
# 107                                  Gridstore            Gridstore
# 108                                  HyperWeek
# 109                                       Meez
# 116                               Titan Gaming  Santa Monica Office
#
#      office latitude  office longitude           city  type
# 0          37.564605       -122.322924  San_Francisco  tech
# 2         -23.548943        -46.638818           None  tech
# 3          40.026000       -105.259041           None  tech
# 4          40.707834        -74.013661       New_York  tech
# 5          32.055400         34.759500           None  tech
# 6          40.445515         -3.706176           None  tech
# 7          12.934960         77.613685           None  tech
# 8          48.856667          2.350987           None  tech
# 12         21.303049       -157.789070           None  tech
# 13         37.564538       -122.325470  San_Francisco  tech
# 14         49.282455       -123.109217           None  tech
# 15         41.406335          2.192023           None  tech
# 17         40.757929        -73.985506       New_York  tech
# 18         42.603532        -83.161340           None  tech
# 20         50.839970          4.346472           None  tech
# 21         39.905226        -86.054702           None  tech
# 22         37.270518       -121.955879  San_Francisco  tech
# 23         52.365758          4.892872           None  tech
# 25         40.740804        -74.007170       New_York  tech
# 26         37.448491       -122.180281  San_Francisco  tech
# 28         21.303049       -157.789070           None  tech
# 33         51.518190         -0.208979           None  tech
# 34         47.391290          8.508289           None  tech
# 39         34.052187       -118.243425    Los_Angeles  tech
# 40         37.665648       -122.384349  San_Francisco  tech
# 43         39.749671       -104.999845           None  tech
# 45         42.364756        -71.103259           None  tech
# 46         42.275263        -71.247620           None  tech
# 48         37.322973       -122.038579  San_Francisco  tech
# 49         47.490346         19.059078           None  tech
# 57         37.446823       -122.161523  San_Francisco  tech
# 58         34.069849       -118.405418    Los_Angeles  tech
# 59         40.733430        -73.990967       New_York  tech
# 60         51.820582          0.011861           None  tech
# 69         42.675189        -71.146900           None  tech
# 70         40.438423        -80.001933           None  tech
# 71         29.784764        -82.476804           None  tech
# 72         37.790554       -122.404149  San_Francisco  tech
# 73         51.519613         -0.102027           None  tech
# 74         40.748104        -74.035379       New_York  tech
# 78         37.566879       -122.323895  San_Francisco  tech
# 79         42.375641        -72.519691           None  tech
# 80         37.556171       -122.078063  San_Francisco  tech
# 81         12.971606         77.594376           None  tech
# 82         39.749671       -104.999845           None  tech
# 83         33.817100       -111.903500           None  tech
# 84         42.318138        -71.247560           None  tech
# 85         40.593239       -105.076650           None  tech
# 88         34.007112       -118.489748    Los_Angeles  tech
# 89         37.525246       -121.917842  San_Francisco  tech
# 90         40.744618        -73.987764       New_York  tech
# 91         40.748104        -74.035379       New_York  tech
# 103        34.047312       -118.445243    Los_Angeles  tech
# 104        47.610301       -122.339978           None  tech
# 107        37.418907       -122.088429  San_Francisco  tech
# 108        46.212146          6.150324           None  tech
# 109        37.785271       -122.397582  San_Francisco  tech
# 116        53.544711       -113.515769           None  tech

# %%
design_data_clean = add_city_name(design_location, cities)
design_data_clean["type"] = "design"
design_data_clean
# Out:
#                 name      office description  office latitude
# 0            SmugMug                                37.390056  \
# 1          Clipmarks                    None        40.757929
# 3            BeFunky                    None        37.774929
# 6              Youku                                31.200657
# 8        Gilt Groupe         New York Office        40.747270
# 9           Smilebox                    None        47.676378
# 10           Howcast           New York City        40.646166
# 11         99designs      United States (HQ)        37.795531
# 12         99designs               Australia       -37.802659
# 13         99designs                  Europe        52.498620
# 14           EatLime                    None        37.774929
# 17  Non-Member Films       West Coast Office        33.989029
# 18  Non-Member Films          Midwest Office        42.330165
# 19         StudioNow                      HQ        36.139960
# 20        Stylesight       NY (Headquarters)        40.730763
# 21  Non-Member Films       West Coast Office        33.989029
# 22  Non-Member Films          Midwest Office        42.330165
# 23         StudioNow                      HQ        36.139960
# 24        Stylesight       NY (Headquarters)        40.730763
# 25           Poptent     Philadelphia Office        40.001874
# 28            Vuclip           Head Quarters        37.406027
# 29            Vuclip                                28.635308
# 30            Vuclip                                19.075984
# 32        Refinery29     Global Headquarters        40.727719
# 33            Geelbe                  Bogotá         4.598056
# 34            Qualvu  Corporate Headquarters        39.661171
# 38            Imagga               Imagga HQ        42.686691
# 40          Graticle                  Office        45.796841
# 43         Chicisimo                  Office        43.264499
#
#     office longitude           city    type
# 0        -122.067692  San_Francisco  design
# 1         -73.985506       New_York  design
# 3        -122.419415  San_Francisco  design
# 6         121.438470           None  design
# 8         -73.980064       New_York  design
# 9        -122.122155           None  design
# 10        -73.889492       New_York  design
# 11       -122.400598  San_Francisco  design
# 12        144.986855           None  design
# 13         13.446903           None  design
# 14       -122.419415  San_Francisco  design
# 17       -118.462421    Los_Angeles  design
# 18        -83.045913           None  design
# 19        -86.796377           None  design
# 20        -74.000827       New_York  design
# 21       -118.462421    Los_Angeles  design
# 22        -83.045913           None  design
# 23        -86.796377           None  design
# 24        -74.000827       New_York  design
# 25        -75.274720           None  design
# 28       -121.918642  San_Francisco  design
# 29         77.224960           None  design
# 30         72.877656           None  design
# 32        -73.950821       New_York  design
# 33        -74.075833           None  design
# 34       -105.352174           None  design
# 38         23.316708           None  design
# 40       -122.693144           None  design
# 43         -2.930832           None  design

# %%
cities_counts_tech = tech_data_clean['city'].value_counts()
cities_counts_tech
# Out:
# city
# San_Francisco    13
# New_York          7
# Los_Angeles       4
# Name: count, dtype: int64

# %%
cities_counts_design = design_data_clean['city'].value_counts()
cities_counts_design
# Out:
# city
# New_York         6
# San_Francisco    5
# Los_Angeles      2
# Name: count, dtype: int64

# %%
final_data_tech = tech_data_clean[tech_data_clean['city'].isin(["San_Francisco", "Los_Angeles", "New_York"])]
final_data_tech
# Out:
#                         name office description  office latitude
# 0                  Sofa Labs                           37.564605  \
# 4          GameChanger Media    New York Office        40.707834
# 13                   Skydeck                           37.564538
# 17                   PeekYou               None        40.757929
# 22                  VisualOn       Headquarters        37.270518
# 25             ChallengePost                           40.740804
# 26                   Factery                           37.448491
# 39                   Magento               None        34.052187
# 40     VistaGen Therapeutics                           37.665648
# 48                   ScaleMP                           37.322973
# 57     Social Gaming Network     HQ Los Angeles        37.446823
# 58     Social Gaming Network                           34.069849
# 59                 Chartbeat                           40.733430
# 72                    Heyzap       Head Quaters        37.790554
# 74                 Integrate      Scottsdale HQ        40.748104
# 78                     Fixya                           37.566879
# 80               BASH Gaming          US Office        37.556171
# 88                    Tongal       Headquarters        34.007112
# 89   Advanced Power Projects                           37.525246
# 90                     Yipit                 HQ        40.744618
# 91                 Integrate      Scottsdale HQ        40.748104
# 103               RazorGator               None        34.047312
# 107                Gridstore          Gridstore        37.418907
# 109                     Meez                           37.785271
#
#      office longitude           city  type
# 0         -122.322924  San_Francisco  tech
# 4          -74.013661       New_York  tech
# 13        -122.325470  San_Francisco  tech
# 17         -73.985506       New_York  tech
# 22        -121.955879  San_Francisco  tech
# 25         -74.007170       New_York  tech
# 26        -122.180281  San_Francisco  tech
# 39        -118.243425    Los_Angeles  tech
# 40        -122.384349  San_Francisco  tech
# 48        -122.038579  San_Francisco  tech
# 57        -122.161523  San_Francisco  tech
# 58        -118.405418    Los_Angeles  tech
# 59         -73.990967       New_York  tech
# 72        -122.404149  San_Francisco  tech
# 74         -74.035379       New_York  tech
# 78        -122.323895  San_Francisco  tech
# 80        -122.078063  San_Francisco  tech
# 88        -118.489748    Los_Angeles  tech
# 89        -121.917842  San_Francisco  tech
# 90         -73.987764       New_York  tech
# 91         -74.035379       New_York  tech
# 103       -118.445243    Los_Angeles  tech
# 107       -122.088429  San_Francisco  tech
# 109       -122.397582  San_Francisco  tech

# %%
final_data_design = design_data_clean[design_data_clean['city'].isin(["San_Francisco", "Los_Angeles", "New_York"])]
final_data_design
# Out:
#                 name   office description  office latitude  office longitude
# 0            SmugMug                             37.390056       -122.067692  \
# 1          Clipmarks                 None        40.757929        -73.985506
# 3            BeFunky                 None        37.774929       -122.419415
# 8        Gilt Groupe      New York Office        40.747270        -73.980064
# 10           Howcast        New York City        40.646166        -73.889492
# 11         99designs   United States (HQ)        37.795531       -122.400598
# 14           EatLime                 None        37.774929       -122.419415
# 17  Non-Member Films    West Coast Office        33.989029       -118.462421
# 20        Stylesight    NY (Headquarters)        40.730763        -74.000827
# 21  Non-Member Films    West Coast Office        33.989029       -118.462421
# 24        Stylesight    NY (Headquarters)        40.730763        -74.000827
# 28            Vuclip        Head Quarters        37.406027       -121.918642
# 32        Refinery29  Global Headquarters        40.727719        -73.950821
#
#              city    type
# 0   San_Francisco  design
# 1        New_York  design
# 3   San_Francisco  design
# 8        New_York  design
# 10       New_York  design
# 11  San_Francisco  design
# 14  San_Francisco  design
# 17    Los_Angeles  design
# 20       New_York  design
# 21    Los_Angeles  design
# 24       New_York  design
# 28  San_Francisco  design
# 32       New_York  design

# %%
final_data = pd.concat([final_data_tech, final_data_design], axis=0)
top_cities = final_data.groupby(['city', 'type'])['name'].agg('count').reset_index()
top_cities
# Out:
#             city    type  name
# 0    Los_Angeles  design     2
# 1    Los_Angeles    tech     4
# 2       New_York  design     6
# 3       New_York    tech     7
# 4  San_Francisco  design     5
# 5  San_Francisco    tech    13

# %%
final_data2 = final_data[final_data['city'].isin(['Los_Angeles', 'New_York', 'San_Francisco'])]
final_data2
# Out:
#                         name   office description  office latitude
# 0                  Sofa Labs                             37.564605  \
# 4          GameChanger Media      New York Office        40.707834
# 13                   Skydeck                             37.564538
# 17                   PeekYou                 None        40.757929
# 22                  VisualOn         Headquarters        37.270518
# 25             ChallengePost                             40.740804
# 26                   Factery                             37.448491
# 39                   Magento                 None        34.052187
# 40     VistaGen Therapeutics                             37.665648
# 48                   ScaleMP                             37.322973
# 57     Social Gaming Network       HQ Los Angeles        37.446823
# 58     Social Gaming Network                             34.069849
# 59                 Chartbeat                             40.733430
# 72                    Heyzap         Head Quaters        37.790554
# 74                 Integrate        Scottsdale HQ        40.748104
# 78                     Fixya                             37.566879
# 80               BASH Gaming            US Office        37.556171
# 88                    Tongal         Headquarters        34.007112
# 89   Advanced Power Projects                             37.525246
# 90                     Yipit                   HQ        40.744618
# 91                 Integrate        Scottsdale HQ        40.748104
# 103               RazorGator                 None        34.047312
# 107                Gridstore            Gridstore        37.418907
# 109                     Meez                             37.785271
# 0                    SmugMug                             37.390056
# 1                  Clipmarks                 None        40.757929
# 3                    BeFunky                 None        37.774929
# 8                Gilt Groupe      New York Office        40.747270
# 10                   Howcast        New York City        40.646166
# 11                 99designs   United States (HQ)        37.795531
# 14                   EatLime                 None        37.774929
# 17          Non-Member Films    West Coast Office        33.989029
# 20                Stylesight    NY (Headquarters)        40.730763
# 21          Non-Member Films    West Coast Office        33.989029
# 24                Stylesight    NY (Headquarters)        40.730763
# 28                    Vuclip        Head Quarters        37.406027
# 32                Refinery29  Global Headquarters        40.727719
#
#      office longitude           city    type
# 0         -122.322924  San_Francisco    tech
# 4          -74.013661       New_York    tech
# 13        -122.325470  San_Francisco    tech
# 17         -73.985506       New_York    tech
# 22        -121.955879  San_Francisco    tech
# 25         -74.007170       New_York    tech
# 26        -122.180281  San_Francisco    tech
# 39        -118.243425    Los_Angeles    tech
# 40        -122.384349  San_Francisco    tech
# 48        -122.038579  San_Francisco    tech
# 57        -122.161523  San_Francisco    tech
# 58        -118.405418    Los_Angeles    tech
# 59         -73.990967       New_York    tech
# 72        -122.404149  San_Francisco    tech
# 74         -74.035379       New_York    tech
# 78        -122.323895  San_Francisco    tech
# 80        -122.078063  San_Francisco    tech
# 88        -118.489748    Los_Angeles    tech
# 89        -121.917842  San_Francisco    tech
# 90         -73.987764       New_York    tech
# 91         -74.035379       New_York    tech
# 103       -118.445243    Los_Angeles    tech
# 107       -122.088429  San_Francisco    tech
# 109       -122.397582  San_Francisco    tech
# 0         -122.067692  San_Francisco  design
# 1          -73.985506       New_York  design
# 3         -122.419415  San_Francisco  design
# 8          -73.980064       New_York  design
# 10         -73.889492       New_York  design
# 11        -122.400598  San_Francisco  design
# 14        -122.419415  San_Francisco  design
# 17        -118.462421    Los_Angeles  design
# 20         -74.000827       New_York  design
# 21        -118.462421    Los_Angeles  design
# 24         -74.000827       New_York  design
# 28        -121.918642  San_Francisco  design
# 32         -73.950821       New_York  design

# %%
top3_map = top3_map(final_data2)
top3_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b653e6c40f22247247274aea593622c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b653e6c40f22247247274aea593622c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b653e6c40f22247247274aea593622c = L.map(
#                 &quot;map_3b653e6c40f22247247274aea593622c&quot;,
#                 {
#                     center: [40.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1db58c2309ed8d49568bee5bda6a1e9d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3b653e6c40f22247247274aea593622c);
#
#
#             var feature_group_fba2df78f8c8048ae7431f6474d93de0 = L.featureGroup(
#                 {}
#             ).addTo(map_3b653e6c40f22247247274aea593622c);
#
#
#             var marker_59233032d95b8a3bd479a43d66d468ef = L.marker(
#                 [37.5646055, -122.3229235],
#                 {}
#             ).addTo(feature_group_fba2df78f8c8048ae7431f6474d93de0);
#
#
#             var icon_97853e384031350f40729b164cbab38a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_59233032d95b8a3bd479a43d66d468ef.setIcon(icon_97853e384031350f40729b164cbab38a);
#
#
#             marker_59233032d95b8a3bd479a43d66d468ef.bindTooltip(
#                 `&lt;div&gt;
#                      Sofa Labs
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9d6f90fd0de144fc56df869066388dab = L.marker(
#                 [40.7078343, -74.0136605],
#                 {}
#             ).addTo(feature_group_fba2df78f8c8048ae7431f6474d93de0);
#
#
#             var icon_acf05d079b1df71e93fdf3275f67a4e4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9d6f90fd0de144fc56df869066388dab.setIcon(icon_acf05d079b1df71e93fdf3275f67a4e4);
#
#
#             marker_9d6f90fd0de144fc56df869066388dab.bindTooltip(
#                 `&lt;div&gt;
#                      GameChanger Media
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f70457feb27e0f113169bd58767449e5 = L.marker(
#                 [37.5645375, -122.3254705],
#                 {}
#             ).addTo(feature_group_fba2df78f8c8048ae7431f6474d93de0);
#
#
#             var icon_a97c46716b5ea597486b11c741292714 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f70457feb27e0f113169bd58767449e5.setIcon(icon_a97c46716b5ea597486b11c741292714);
#
#
#             marker_f70457feb27e0f113169bd58767449e5.bindTooltip(
#                 `&lt;div&gt;
#                      Skydeck
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ae2b22adc8dea3b2315c513c59a8ecb4 = L.marker(
#                 [40.757929, -73.985506],
#                 {}
#             ).addTo(feature_group_fba2df78f8c8048ae7431f6474d93de0);
#
#
#             var icon_4ff8d7d2aae7725c42e0fc9bbf5f58a8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ae2b22adc8dea3b2315c513c59a8ecb4.setIcon(icon_4ff8d7d2aae7725c42e0fc9bbf5f58a8);
#
#
#             marker_ae2b22adc8dea3b2315c513c59a8ecb4.bindTooltip(
#                 `&lt;div&gt;
#                      PeekYou
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_21a4eaeda071aaacd74a0f767840a581 = L.marker(
#                 [37.270518, -121.955879],
#                 {}
#             ).addTo(feature_group_fba2df78f8c8048ae7431f6474d93de0);
#
#
#             var icon_03ca7ea3d1fbd9ca4efc334965b298d5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot

# %%
top3_map.fit_bounds([[37.8,-122.4],[37.5,-122.1]], padding=(5,5))
top3_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b653e6c40f22247247274aea593622c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b653e6c40f22247247274aea593622c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b653e6c40f22247247274aea593622c = L.map(
#                 &quot;map_3b653e6c40f22247247274aea593622c&quot;,
#                 {
#                     center: [40.0, -99.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1db58c2309ed8d49568bee5bda6a1e9d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3b653e6c40f22247247274aea593622c);
#
#
#             var feature_group_fba2df78f8c8048ae7431f6474d93de0 = L.featureGroup(
#                 {}
#             ).addTo(map_3b653e6c40f22247247274aea593622c);
#
#
#             var marker_59233032d95b8a3bd479a43d66d468ef = L.marker(
#                 [37.5646055, -122.3229235],
#                 {}
#             ).addTo(feature_group_fba2df78f8c8048ae7431f6474d93de0);
#
#
#             var icon_97853e384031350f40729b164cbab38a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_59233032d95b8a3bd479a43d66d468ef.setIcon(icon_97853e384031350f40729b164cbab38a);
#
#
#             marker_59233032d95b8a3bd479a43d66d468ef.bindTooltip(
#                 `&lt;div&gt;
#                      Sofa Labs
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9d6f90fd0de144fc56df869066388dab = L.marker(
#                 [40.7078343, -74.0136605],
#                 {}
#             ).addTo(feature_group_fba2df78f8c8048ae7431f6474d93de0);
#
#
#             var icon_acf05d079b1df71e93fdf3275f67a4e4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_9d6f90fd0de144fc56df869066388dab.setIcon(icon_acf05d079b1df71e93fdf3275f67a4e4);
#
#
#             marker_9d6f90fd0de144fc56df869066388dab.bindTooltip(
#                 `&lt;div&gt;
#                      GameChanger Media
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f70457feb27e0f113169bd58767449e5 = L.marker(
#                 [37.5645375, -122.3254705],
#                 {}
#             ).addTo(feature_group_fba2df78f8c8048ae7431f6474d93de0);
#
#
#             var icon_a97c46716b5ea597486b11c741292714 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_f70457feb27e0f113169bd58767449e5.setIcon(icon_a97c46716b5ea597486b11c741292714);
#
#
#             marker_f70457feb27e0f113169bd58767449e5.bindTooltip(
#                 `&lt;div&gt;
#                      Skydeck
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ae2b22adc8dea3b2315c513c59a8ecb4 = L.marker(
#                 [40.757929, -73.985506],
#                 {}
#             ).addTo(feature_group_fba2df78f8c8048ae7431f6474d93de0);
#
#
#             var icon_4ff8d7d2aae7725c42e0fc9bbf5f58a8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_ae2b22adc8dea3b2315c513c59a8ecb4.setIcon(icon_4ff8d7d2aae7725c42e0fc9bbf5f58a8);
#
#
#             marker_ae2b22adc8dea3b2315c513c59a8ecb4.bindTooltip(
#                 `&lt;div&gt;
#                      PeekYou
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_21a4eaeda071aaacd74a0f767840a581 = L.marker(
#                 [37.270518, -121.955879],
#                 {}
#             ).addTo(feature_group_fba2df78f8c8048ae7431f6474d93de0);
#
#
#             var icon_03ca7ea3d1fbd9ca4efc334965b298d5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;briefcase&quot
